# %% [markdown]
# ### All the possible combinations are 12 for AgeGroup = ["Preschooler", "MiddleSchool", "Teenager"] || Gender = ["M", "F"] || ADHD_NoADHD = [0, 1] are :
#
# 1. Preschooler, Male, ADHD: (Preschooler, M, 1)
#
# 2. Preschooler, Male, No ADHD: (Preschooler, M, 0)
#
# 3. Preschooler, Female, ADHD: (Preschooler, F, 1)
#
# 4. Preschooler, Female, No ADHD: (Preschooler, F, 0)
#
# 5. MiddleChildhood, Male, ADHD: (MiddleChildhood, M, 1)
#
# 6. MiddleChildhood, Male, No ADHD: (MiddleChildhood, M, 0)
#
# 7. MiddleChildhood, Female, ADHD: (MiddleChildhood, F, 1)
#
# 8. MiddleChildhood, Female, No ADHD: (MiddleChildhood, F, 0)
#
# 9. Teenager, Male, ADHD: (Teenager, M, 1)
#
# 10. Teenager, Male, No ADHD: (Teenager, M, 0)
#
# 11. Teenager, Female, ADHD: (Teenager, F, 1)
#
# 12. Teenager, Female, No ADHD: (Teenager, F, 0)

# %% [markdown]
# #### 1. Patient trajectory plot which satify this condition Gender = M, AgeGroup = PreSchooler and ADHD(Attention Deficit Hyperactivity Disorder) = 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplot_patient_trajectory import MatplotlibPatientTrajectory

# Load your CSV data
original_df = pd.read_csv(
    "/mnt/work/workbench/dipendrp/Paper3/Data/SubDataset_PreSchooler_M_ADHD.csv"
)
print(len(original_df))
print(original_df["cluster"].value_counts())
# Create an instance of MatplotlibPatientTrajectory
patient_trajectory = MatplotlibPatientTrajectory()

# Call the load_data method
processed_df = patient_trajectory.load_data(original_df)

# Work with the processed_df as needed
processed_df = processed_df.head(50)
custom_colors = ["orange", "green", "blue"]
unique_patients = processed_df["pasient"].unique()
fig, axes = plt.subplots(1, 1, figsize=(30, 14))
fig.suptitle(
    "Pre-schooler, Male, ADHD patient with age, gender, cluster label, diagnosis and medication during each episode"
)
fig.tight_layout(pad=2)
patient_trajectory.patient_timeline_plot_yearly(
    processed_df, axes, custom_colors, unique_patients
)
plt.tight_layout()
plt.show()
plt.savefig("PreSchooler_M_ADHD.png", dpi=300, bbox_inches="tight")
# Out:
# 386
# cluster
# 2    209
# 1    162
# 0     15
# Name: count, dtype: int64

# %% [markdown]
# #### 2. Patient trajectory plot which satify this condition Age = M, AgeGroup = PreSchooler and ADHD_NoADHD = 0

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplot_patient_trajectory import MatplotlibPatientTrajectory

# Load your CSV data
original_df = pd.read_csv(
    "/mnt/work/workbench/dipendrp/Paper3/Data/SubDataset_PreSchooler_M_NoADHD.csv"
)
print(len(original_df))
print(original_df["cluster"].value_counts())
# Create an instance of MatplotlibPatientTrajectory
patient_trajectory = MatplotlibPatientTrajectory()

# Call the load_data method
processed_df = patient_trajectory.load_data(original_df)

# Work with the processed_df as needed
processed_df = processed_df.head(50)
custom_colors = ["orange", "green", "blue"]
unique_patients = processed_df["pasient"].unique()
fig, axes = plt.subplots(1, 1, figsize=(30, 14))
fig.suptitle(
    "Pre-school,Male, No ADHD with age, gender, cluster label, diagnosis and medication during each episode"
)
fig.tight_layout(pad=2)
patient_trajectory.patient_timeline_plot_yearly(
    processed_df, axes, custom_colors, unique_patients
)
plt.tight_layout()
plt.show()
plt.savefig("PreSchooler_M_NoADHD.png", dpi=300, bbox_inches="tight")
# Out:
# 648
# cluster
# 1    582
# 2     50
# 0     16
# Name: count, dtype: int64

# %% [markdown]
# #### 3. Patient trajectory plot which satify this condition Gender = F, AgeGroup = PreSchooler and ADHD_NoADHD = 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplot_patient_trajectory import MatplotlibPatientTrajectory

# Load your CSV data
original_df = pd.read_csv(
    "/mnt/work/workbench/dipendrp/Paper3/Data/SubDataset_PreSchooler_F_ADHD.csv"
)
print(len(original_df))
print(original_df["cluster"].value_counts())
# Create an instance of MatplotlibPatientTrajectory
patient_trajectory = MatplotlibPatientTrajectory()

# Call the load_data method
processed_df = patient_trajectory.load_data(original_df)

# Work with the processed_df as needed
processed_df = processed_df.head(50)
custom_colors = ["orange", "green", "blue"]
unique_patients = processed_df["pasient"].unique()
fig, axes = plt.subplots(1, 1, figsize=(30, 14))
fig.suptitle(
    "Pre-school,Female, ADHD with age, gender, cluster label, diagnosis and medication during each episode"
)
fig.tight_layout(pad=2)
patient_trajectory.patient_timeline_plot_yearly(
    processed_df, axes, custom_colors, unique_patients
)
plt.tight_layout()
plt.show()
plt.savefig("PreSchooler_F_ADHD.png", dpi=300, bbox_inches="tight")
# Out:
# 120
# cluster
# 2    66
# 1    54
# Name: count, dtype: int64

# %% [markdown]
# #### 4. Patient trajectory plot which satify this condition Gender = F, AgeGroup = PreSchooler and ADHD_NoADHD = 0

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplot_patient_trajectory import MatplotlibPatientTrajectory

# Load your CSV data
original_df = pd.read_csv(
    "/mnt/work/workbench/dipendrp/Paper3/Data/SubDataset_PreSchooler_F_NoADHD.csv"
)
print(len(original_df))
print(original_df["cluster"].value_counts())
# Create an instance of MatplotlibPatientTrajectory
patient_trajectory = MatplotlibPatientTrajectory()

# Call the load_data method
processed_df = patient_trajectory.load_data(original_df)

# Work with the processed_df as needed
processed_df = processed_df.head(50)
custom_colors = ["orange", "green", "blue"]
unique_patients = processed_df["pasient"].unique()
fig, axes = plt.subplots(1, 1, figsize=(30, 14))
fig.suptitle(
    "PreSchooler, Female, No ADHD patient with age, gender, cluster label, diagnosis and medication during each episode"
)
fig.tight_layout(pad=2)
patient_trajectory.patient_timeline_plot_yearly(
    processed_df, axes, custom_colors, unique_patients
)
plt.tight_layout()
plt.show()
plt.savefig("PreSchooler_F_NoADHD.png")
# Out:
# 493
# cluster
# 1    447
# 2     34
# 0     12
# Name: count, dtype: int64

# %% [markdown]
# #### 5. Patient trajectory plot which satify this condition Gender = M, AgeGroup = MiddleChildhood and ADHD_NoADHD = 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplot_patient_trajectory import MatplotlibPatientTrajectory

# Load your CSV data
original_df = pd.read_csv(
    "/mnt/work/workbench/dipendrp/Paper3/Data/SubDataset_MiddleChildhood_M_ADHD.csv"
)
print(len(original_df))
print(original_df["cluster"].value_counts())
# Create an instance of MatplotlibPatientTrajectory
patient_trajectory = MatplotlibPatientTrajectory()

# Call the load_data method
processed_df = patient_trajectory.load_data(original_df)

# Work with the processed_df as needed
processed_df = processed_df.head(50)
custom_colors = ["orange", "green", "blue"]
unique_patients = processed_df["pasient"].unique()
fig, axes = plt.subplots(1, 1, figsize=(30, 14))
fig.suptitle(
    "Middle Childhood, Male, ADHD patient  trajectory with age, gender, cluster label, diagnosis and medication during each episode"
)
fig.tight_layout(pad=2)
patient_trajectory.patient_timeline_plot_yearly(
    processed_df, axes, custom_colors, unique_patients
)
plt.tight_layout()
plt.show()
plt.savefig("MiddleChildhood_M_ADHD.png", dpi=300, bbox_inches="tight")
# Out:
# 2158
# cluster
# 2    1313
# 1     801
# 0      44
# Name: count, dtype: int64

# %% [markdown]
# #### 6. Patient trajectory plot which satify this condition Gender = M, AgeGroup = MiddleChildhood and ADHD_NoADHD = 0

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplot_patient_trajectory import MatplotlibPatientTrajectory

# Load your CSV data
original_df = pd.read_csv(
    "/mnt/work/workbench/dipendrp/Paper3/Data/SubDataset_MiddleChildhood_M_NoADHD.csv"
)
print(len(original_df))
print(original_df["cluster"].value_counts())
# Create an instance of MatplotlibPatientTrajectory
patient_trajectory = MatplotlibPatientTrajectory()

# Call the load_data method
processed_df = patient_trajectory.load_data(original_df)

# Work with the processed_df as needed
processed_df = processed_df.head(50)
custom_colors = ["orange", "green", "blue"]
unique_patients = processed_df["pasient"].unique()
fig, axes = plt.subplots(1, 1, figsize=(30, 14))
fig.suptitle(
    "Middle Childhood, Male, No ADHD patient  trajectory with age, gender, cluster label, diagnosis and medication during each episode"
)
fig.tight_layout(pad=2)
patient_trajectory.patient_timeline_plot_yearly(
    processed_df, axes, custom_colors, unique_patients
)
plt.tight_layout()
plt.show()
plt.savefig("MiddleChildhood_M_NoADHD.png", dpi=300, bbox_inches="tight")
# Out:
# 1917
# cluster
# 1    1632
# 2     211
# 0      74
# Name: count, dtype: int64

# %% [markdown]
# #### 7. Patient trajectory plot which satify this condition Gender = F, AgeGroup = MiddleChildhood and ADHD_NoADHD = 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplot_patient_trajectory import MatplotlibPatientTrajectory

# Load your CSV data
original_df = pd.read_csv(
    "/mnt/work/workbench/dipendrp/Paper3/Data/SubDataset_MiddleChildhood_F_ADHD.csv"
)
print(len(original_df))
print(original_df["cluster"].value_counts())
# Create an instance of MatplotlibPatientTrajectory
patient_trajectory = MatplotlibPatientTrajectory()

# Call the load_data method
processed_df = patient_trajectory.load_data(original_df)

# Work with the processed_df as needed
processed_df = processed_df.head(50)
custom_colors = ["orange", "green", "blue"]
unique_patients = processed_df["pasient"].unique()
fig, axes = plt.subplots(1, 1, figsize=(30, 14))
fig.suptitle(
    "Middle Childhood, Female, ADHD patient  trajectory with age, gender, cluster label, diagnosis and medication during each episode"
)
fig.tight_layout(pad=2)
patient_trajectory.patient_timeline_plot_yearly(
    processed_df, axes, custom_colors, unique_patients
)
plt.tight_layout()
plt.show()
plt.savefig("MiddleChildhood_F_ADHD.png", dpi=300, bbox_inches="tight")
# Out:
# 745
# cluster
# 2    435
# 1    298
# 0     12
# Name: count, dtype: int64

# %% [markdown]
# #### 8. Patient trajectory plot which satify this condition Gender = F, AgeGroup = MiddleChildhood and ADHD_NoADHD = 0

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplot_patient_trajectory import MatplotlibPatientTrajectory

# Load your CSV data
original_df = pd.read_csv(
    "/mnt/work/workbench/dipendrp/Paper3/Data/SubDataset_MiddleChildhood_F_NoADHD.csv"
)
print(len(original_df))
print(original_df["cluster"].value_counts())
# Create an instance of MatplotlibPatientTrajectory
patient_trajectory = MatplotlibPatientTrajectory()

# Call the load_data method
processed_df = patient_trajectory.load_data(original_df)

# Work with the processed_df as needed
processed_df = processed_df.head(50)
custom_colors = ["orange", "green", "blue"]
unique_patients = processed_df["pasient"].unique()
fig, axes = plt.subplots(1, 1, figsize=(30, 14))
fig.suptitle(
    "Middle Childhood, Female, No ADHD patient  trajectory with age, gender, cluster label, diagnosis and medication during each episode"
)
fig.tight_layout(pad=2)
patient_trajectory.patient_timeline_plot_yearly(
    processed_df, axes, custom_colors, unique_patients
)
plt.tight_layout()
plt.show()
plt.savefig("MiddleChildhood_F_NoADHD.png", dpi=300, bbox_inches="tight")
# Out:
# 1287
# cluster
# 1    1121
# 2     124
# 0      42
# Name: count, dtype: int64

# %% [markdown]
# #### 9. Patient trajectory plot which satify this condition Gender = M, AgeGroup = Teenager and ADHD_NoADHD = 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplot_patient_trajectory import MatplotlibPatientTrajectory

# Load your CSV data
original_df = pd.read_csv(
    "/mnt/work/workbench/dipendrp/Paper3/Data/SubDataset_Teenager_M_ADHD.csv"
)
print(len(original_df))
print(original_df["cluster"].value_counts())
# Create an instance of MatplotlibPatientTrajectory
patient_trajectory = MatplotlibPatientTrajectory()

# Call the load_data method
processed_df = patient_trajectory.load_data(original_df)

# Work with the processed_df as needed
processed_df = processed_df.head(50)
custom_colors = ["orange", "green", "blue"]
unique_patients = processed_df["pasient"].unique()
fig, axes = plt.subplots(1, 1, figsize=(30, 14))
fig.suptitle(
    "Teenager, Male, ADHD patient  trajectory with age, gender, cluster label, diagnosis and medication during each episode"
)
fig.tight_layout(pad=2)
patient_trajectory.patient_timeline_plot_yearly(
    processed_df, axes, custom_colors, unique_patients
)
plt.tight_layout()
plt.show()
plt.savefig("Teenager_M_ADHD.png", dpi=300, bbox_inches="tight")
# Out:
# 1409
# cluster
# 1    893
# 2    466
# 0     50
# Name: count, dtype: int64

# %% [markdown]
# #### 10. Patient trajectory plot which satify this condition Gender = M, AgeGroup = Teenager and ADHD_NoADHD = 0

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplot_patient_trajectory import MatplotlibPatientTrajectory

# Load your CSV data
original_df = pd.read_csv(
    "/mnt/work/workbench/dipendrp/Paper3/Data/SubDataset_Teenager_M_NoADHD.csv"
)
print(len(original_df))
print(original_df["cluster"].value_counts())
# Create an instance of MatplotlibPatientTrajectory
patient_trajectory = MatplotlibPatientTrajectory()

# Call the load_data method
processed_df = patient_trajectory.load_data(original_df)

# Work with the processed_df as needed
processed_df = processed_df.head(50)
custom_colors = ["orange", "green", "blue"]
unique_patients = processed_df["pasient"].unique()
fig, axes = plt.subplots(1, 1, figsize=(30, 14))
fig.suptitle(
    "Teenager, Male, No ADHD patient  trajectory with age, gender, cluster label, diagnosis and medication during each episode"
)
fig.tight_layout(pad=2)
patient_trajectory.patient_timeline_plot_yearly(
    processed_df, axes, custom_colors, unique_patients
)
plt.tight_layout()
plt.show()
plt.savefig("Teenager_M_NoADHD.png", dpi=300, bbox_inches="tight")
# Out:
# 2006
# cluster
# 1    1636
# 0     191
# 2     179
# Name: count, dtype: int64

# %% [markdown]
# #### 11. Patient trajectory plot which satify this condition Gender = F, AgeGroup = Teenager and ADHD_NoADHD = 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplot_patient_trajectory import MatplotlibPatientTrajectory

# Load your CSV data
original_df = pd.read_csv(
    "/mnt/work/workbench/dipendrp/Paper3/Data/SubDataset_Teenager_F_ADHD.csv"
)
print(len(original_df))
print(original_df["cluster"].value_counts())
# Create an instance of MatplotlibPatientTrajectory
patient_trajectory = MatplotlibPatientTrajectory()

# Call the load_data method
processed_df = patient_trajectory.load_data(original_df)

# Work with the processed_df as needed
processed_df = processed_df.head(50)
custom_colors = ["orange", "green", "blue"]
unique_patients = processed_df["pasient"].unique()
fig, axes = plt.subplots(1, 1, figsize=(30, 14))
fig.suptitle(
    "Teenager, Female, ADHD patient  trajectory with age, gender, cluster label, diagnosis and medication during each episode"
)
fig.tight_layout(pad=2)
patient_trajectory.patient_timeline_plot_yearly(
    processed_df, axes, custom_colors, unique_patients
)
plt.tight_layout()
plt.show()
plt.savefig("Teenager_F_ADHD.png", dpi=300, bbox_inches="tight")
# Out:
# 927
# cluster
# 1    461
# 2    422
# 0     44
# Name: count, dtype: int64

# %% [markdown]
# #### 12. Patient trajectory plot which satify this condition Gender = F, AgeGroup = Teenager and ADHD_NoADHD = 0

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplot_patient_trajectory import MatplotlibPatientTrajectory

# Load your CSV data
original_df = pd.read_csv(
    "/mnt/work/workbench/dipendrp/Paper3/Data/SubDataset_Teenager_F_NoADHD.csv"
)
print(len(original_df))
print(original_df["cluster"].value_counts())
# Create an instance of MatplotlibPatientTrajectory
patient_trajectory = MatplotlibPatientTrajectory()

# Call the load_data method
processed_df = patient_trajectory.load_data(original_df)

# Work with the processed_df as needed
processed_df = processed_df.head(50)
custom_colors = ["orange", "green", "blue"]
unique_patients = processed_df["pasient"].unique()
fig, axes = plt.subplots(1, 1, figsize=(30, 14))
fig.suptitle(
    "Teenager, Female, No ADHD patient  trajectory with age, gender, cluster label, diagnosis and medication during each episode"
)
fig.tight_layout(pad=2)
patient_trajectory.patient_timeline_plot_yearly(
    processed_df, axes, custom_colors, unique_patients
)
plt.tight_layout()
plt.show()
plt.savefig("Teenager_F_NoADHD.png", dpi=300, bbox_inches="tight")
# Out:
# 4056
# cluster
# 1    3135
# 2     506
# 0     415
# Name: count, dtype: int64

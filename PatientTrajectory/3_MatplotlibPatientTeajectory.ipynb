# %% [markdown]
# ### All the possible combinations are 12 for `AgeGroup = ["Preschooler"`, `"MiddleSchool", "Teenager"]` || `Gender = ["M", "F"]` || `ADHD = [0, 1]` are :
#
# 1. Preschooler, Male, ADHD: (Preschooler, M, 1)
#
# 2. Preschooler, Male, No ADHD: (Preschooler, M, 0)
#
# 3. Preschooler, Female, ADHD: (Preschooler, F, 1)
#
# 4. Preschooler, Female, No ADHD: (Preschooler, F, 0)
#
# 5. MiddleChildhood, Male, ADHD: (MiddleChildhood, M, 1)
#
# 6. MiddleChildhood, Male, No ADHD: (MiddleChildhood, M, 0)
#
# 7. MiddleChildhood, Female, ADHD: (MiddleChildhood, F, 1)
#
# 8. MiddleChildhood, Female, No ADHD: (MiddleChildhood, F, 0)
#
# 9. Teenager, Male, ADHD: (Teenager, M, 1)
#
# 10. Teenager, Male, No ADHD: (Teenager, M, 0)
#
# 11. Teenager, Female, ADHD: (Teenager, F, 1)
#
# 12. Teenager, Female, No ADHD: (Teenager, F, 0)

# %% [markdown]
# **For including in the paper will use these plots below**
# #### A.1. Patient trajectory plot based on patient age for `Gender = M`, `AgeGroup = PreSchooler` and `ADHD(Attention Deficit Hyperactivity Disorder) = 1`
#
# #### A.2. Patient trajectory plot based on patient id for `Gender = M`, `AgeGroup = PreSchooler` and `ADHD(Attention Deficit Hyperactivity Disorder) = 1`

# %%
####################################################################################################
# A.1. Patient trajectory plot based on patient age for `Gender = M`, `AgeGroup = PreSchooler` and `ADHD(Attention Deficit Hyperactivity Disorder) = 1`
####################################################################################################
from matplot_patient_trajectory import MatplotlibPatientTrajectory
from allpackages import warnings, ast, os, pd, load_dotenv
import matplotlib.pyplot as plt

load_dotenv()

# Get SubsetDataset folder path from environment variables & read subset dataset CSV file
subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset = os.path.join(
    subset_dataset_folder, "SubDataset_PreSchooler_M_ADHD.csv"
)

original_df = pd.read_csv(subset_dataset)
# Select the patient using pasient id and episode associated with the patient, if patient id doesnt exist then raise error saying patient doesnt exist.
# Then save the patient data to a dataframe original_df

try:
    original_df = original_df[original_df["pasient"] == 15869]
    # Create an instance of MatplotlibPatientTrajectory
    patient_trajectory = MatplotlibPatientTrajectory()

    # Call the load_data method
    processed_df = patient_trajectory.load_data(original_df)

    # Work with the processed_df as needed
    custom_colors = ["red", "green", "purple"]
    unique_patients = processed_df["pasient"].unique()
    fig, axes = plt.subplots(1, 1, figsize=(8, 2))
    # fig.suptitle(
    #     "Pre-schooler, Male, ADHD patient with age, count visit, cluster label, diagnosis and medication during each episode"
    # )
    fig.tight_layout(pad=2)
    patient_trajectory.patient_timeline_plot_yearly(
        processed_df, axes, custom_colors, unique_patients
    )
    fig.show()

    FigureTrajectory_folder = os.getenv("FigureTrajectory")
    fig.savefig(
        os.path.join(FigureTrajectory_folder, "PreSchooler_M_ADHD_age_1.eps"),
        dpi=300,
        bbox_inches="tight",
    )
except KeyError:
    print("Patient does not exist")
    raise

# %%
# #### A.2. Patient trajectory plot based on patient id for `Gender = M`, `AgeGroup = PreSchooler` and `ADHD(Attention Deficit Hyperactivity Disorder) = 1`
from matplot_patient_trajectory import MatplotlibPatientTrajectory
from allpackages import warnings, ast, os, pd, load_dotenv
import matplotlib.pyplot as plt

load_dotenv()

# Get SubsetDataset folder path from environment variables & read subset dataset CSV file
subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset = os.path.join(
    subset_dataset_folder, "SubDataset_PreSchooler_M_ADHD.csv"
)

original_df = pd.read_csv(subset_dataset)
print(original_df["cluster"].value_counts())
# Create an instance of MatplotlibPatientTrajectory
patient_trajectory = MatplotlibPatientTrajectory()

# Call the load_data method
processed_df = patient_trajectory.load_data(original_df)

# Select the first fifty patients based on their patient id
selected_patients = processed_df["pasient"].unique()[:20]

# Filter the episodes associated with the selected patients
processed_df = processed_df[processed_df["pasient"].isin(selected_patients)]

custom_colors = ["red", "green", "purple"]
unique_patients = processed_df["pasient"].unique()
fig, axes = plt.subplots(1, 1, figsize=(20, 10))
fig.tight_layout(pad=2)
patient_trajectory.patient_timeline_plot_yearly(
    processed_df, axes, custom_colors, unique_patients
)
fig.show()

FigureTrajectory_folder = os.getenv("FigureTrajectory")
fig.savefig(
    os.path.join(FigureTrajectory_folder, "PreSchooler_M_ADHD.eps"),
    dpi=300,
    bbox_inches="tight",
)

# %% [markdown]
# #### 1. Patient trajectory plot which satisfy this condition `Gender = M`, `AgeGroup = PreSchooler` and `ADHD(Attention Deficit Hyperactivity Disorder) = 1`
#
# **Plots below are 50 patient sorted with `initial_age`, `Length_of_Episode`**

# %%
from matplot_patient_trajectory import MatplotlibPatientTrajectory
from allpackages import warnings, ast, os, pd, load_dotenv
import matplotlib.pyplot as plt

load_dotenv()

# Get SubsetDataset folder path from environment variables & read subset dataset CSV file
subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset = os.path.join(
    subset_dataset_folder, "SubDataset_PreSchooler_M_ADHD.csv"
)

original_df = pd.read_csv(subset_dataset)
print(original_df["cluster"].value_counts())
# Create an instance of MatplotlibPatientTrajectory
patient_trajectory = MatplotlibPatientTrajectory()

# Call the load_data method
processed_df = patient_trajectory.load_data(original_df)

# Select the first fifty patients based on their patient id
selected_patients = processed_df["pasient"].unique()[:50]

# Filter the episodes associated with the selected patients
processed_df = processed_df[processed_df["pasient"].isin(selected_patients)]

custom_colors = ["red", "green", "purple"]
unique_patients = processed_df["pasient"].unique()
fig, axes = plt.subplots(1, 1, figsize=(30, 14))
fig.suptitle(
    "Pre-schooler, Male, ADHD patient with age, count visit, cluster label, diagnosis and medication during each episode"
)
fig.tight_layout(pad=2)
patient_trajectory.patient_timeline_plot_yearly(
    processed_df, axes, custom_colors, unique_patients
)
fig.show()

FigureTrajectory_folder = os.getenv("FigureTrajectory")
fig.savefig(
    os.path.join(FigureTrajectory_folder, "PreSchooler_M_ADHD.jpg"),
    dpi=300,
    bbox_inches="tight",
)

# %% [markdown]
# #### 2. Patient trajectory plot which satify this condition `Age = M`, `AgeGroup = PreSchooler` and `ADHD = 0`

# %%
from matplot_patient_trajectory import MatplotlibPatientTrajectory
from allpackages import warnings, ast, os, pd, load_dotenv
import matplotlib.pyplot as plt

load_dotenv()

# Get SubsetDataset folder path from environment variables & read subset dataset CSV file
subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset = os.path.join(
    subset_dataset_folder, "SubDataset_PreSchooler_M_NoADHD.csv"
)
original_df = pd.read_csv(subset_dataset)

print(original_df["cluster"].value_counts())
# Create an instance of MatplotlibPatientTrajectory
patient_trajectory = MatplotlibPatientTrajectory()

# Call the load_data method
processed_df = patient_trajectory.load_data(original_df)

# Select the first fifty patients based on their patient id
selected_patients = processed_df["pasient"].unique()[:50]

# Filter the episodes associated with the selected patients
processed_df = processed_df[processed_df["pasient"].isin(selected_patients)]

custom_colors = ["red", "green", "purple"]
unique_patients = processed_df["pasient"].unique()
fig, axes = plt.subplots(1, 1, figsize=(30, 14))
fig.suptitle(
    "Pre-school,Male, No ADHD with age, count visit, cluster label, diagnosis and medication during each episode"
)
fig.tight_layout(pad=2)
patient_trajectory.patient_timeline_plot_yearly(
    processed_df, axes, custom_colors, unique_patients
)

fig.show()

FigureTrajectory_folder = os.getenv("FigureTrajectory")
fig.savefig(
    os.path.join(FigureTrajectory_folder, "PreSchooler_M_NoADHD.jpg"),
    dpi=300,
    bbox_inches="tight",
)

# %% [markdown]
# #### 3. Patient trajectory plot which satify this condition `Gender = F`, `AgeGroup = PreSchooler` and `ADHD = 1`

# %%
from matplot_patient_trajectory import MatplotlibPatientTrajectory
from allpackages import warnings, ast, os, pd, load_dotenv
import matplotlib.pyplot as plt

load_dotenv()

# Get SubsetDataset folder path from environment variables & read subset dataset CSV file
subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset = os.path.join(
    subset_dataset_folder, "SubDataset_PreSchooler_F_ADHD.csv"
)
original_df = pd.read_csv(subset_dataset)

print(original_df["cluster"].value_counts())
# Create an instance of MatplotlibPatientTrajectory
patient_trajectory = MatplotlibPatientTrajectory()

# Call the load_data method
processed_df = patient_trajectory.load_data(original_df)

# Select the first fifty patients based on their patient id
selected_patients = processed_df["pasient"].unique()[:50]

# Filter the episodes associated with the selected patients
processed_df = processed_df[processed_df["pasient"].isin(selected_patients)]

custom_colors = ["red", "green", "purple"]
unique_patients = processed_df["pasient"].unique()
fig, axes = plt.subplots(1, 1, figsize=(30, 14))
fig.suptitle(
    "Pre-school,Female, ADHD with age, count visit, cluster label, diagnosis and medication during each episode"
)
fig.tight_layout(pad=2)
patient_trajectory.patient_timeline_plot_yearly(
    processed_df, axes, custom_colors, unique_patients
)
fig.show()

FigureTrajectory_folder = os.getenv("FigureTrajectory")
fig.savefig(
    os.path.join(FigureTrajectory_folder, "PreSchooler_F_ADHD.jpg"),
    dpi=300,
    bbox_inches="tight",
)

# %% [markdown]
# #### 4. Patient trajectory plot which satify this condition `Gender = F`, `AgeGroup = PreSchooler` and `ADHD = 0`

# %%
from matplot_patient_trajectory import MatplotlibPatientTrajectory
from allpackages import warnings, ast, os, pd, load_dotenv
import matplotlib.pyplot as plt

load_dotenv()

# Get SubsetDataset folder path from environment variables & read subset dataset CSV file
subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset = os.path.join(
    subset_dataset_folder, "SubDataset_PreSchooler_F_NoADHD.csv"
)
original_df = pd.read_csv(subset_dataset)

print(original_df["cluster"].value_counts())
# Create an instance of MatplotlibPatientTrajectory
patient_trajectory = MatplotlibPatientTrajectory()

# Call the load_data method
processed_df = patient_trajectory.load_data(original_df)

# Select the first fifty patients based on their patient id
selected_patients = processed_df["pasient"].unique()[:50]

# Filter the episodes associated with the selected patients
processed_df = processed_df[processed_df["pasient"].isin(selected_patients)]

custom_colors = ["red", "green", "purple"]
unique_patients = processed_df["pasient"].unique()
fig, axes = plt.subplots(1, 1, figsize=(30, 14))
fig.suptitle(
    "PreSchooler, Female, No ADHD patient with age, count visit, cluster label, diagnosis and medication during each episode"
)
fig.tight_layout(pad=2)
patient_trajectory.patient_timeline_plot_yearly(
    processed_df, axes, custom_colors, unique_patients
)

fig.show()

FigureTrajectory_folder = os.getenv("FigureTrajectory")
fig.savefig(
    os.path.join(FigureTrajectory_folder, "PreSchooler_F_NoADHD.jpg"),
    dpi=300,
    bbox_inches="tight",
)

# %% [markdown]
# #### 5. Patient trajectory plot which satify this condition `Gender = M`, `AgeGroup = MiddleChildhood` and `ADHD = 1`

# %%
from matplot_patient_trajectory import MatplotlibPatientTrajectoryMiddleChildhood
from allpackages import warnings, ast, os, pd, load_dotenv
import matplotlib.pyplot as plt

load_dotenv()

# Get SubsetDataset folder path from environment variables & read subset dataset CSV file
subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset = os.path.join(
    subset_dataset_folder, "SubDataset_MiddleChildhood_M_ADHD.csv"
)
original_df = pd.read_csv(subset_dataset)

print(original_df["cluster"].value_counts())
# Create an instance of MatplotlibPatientTrajectory
patient_trajectory = MatplotlibPatientTrajectoryMiddleChildhood()

# Call the load_data method
processed_df = patient_trajectory.load_data(original_df)

# Select the first fifty patients based on their patient id
selected_patients = processed_df["pasient"].unique()[:50]

# Filter the episodes associated with the selected patients
processed_df = processed_df[processed_df["pasient"].isin(selected_patients)]

custom_colors = ["red", "green", "purple"]
unique_patients = processed_df["pasient"].unique()
fig, axes = plt.subplots(1, 1, figsize=(30, 14))
fig.suptitle(
    "Middle Childhood, Male, ADHD patient  trajectory with age, count visit, cluster label, diagnosis and medication during each episode"
)
fig.tight_layout(pad=2)
patient_trajectory.patient_timeline_plot_yearly(
    processed_df, axes, custom_colors, unique_patients
)
fig.show()

FigureTrajectory_folder = os.getenv("FigureTrajectory")
fig.savefig(
    os.path.join(FigureTrajectory_folder, "MiddleChildhood_M_ADHD.jpg"),
    dpi=300,
    bbox_inches="tight",
)

# %% [markdown]
# #### 6. Patient trajectory plot which satify this condition `Gender = M`, `AgeGroup = MiddleChildhood` and `ADHD = 0`

# %%
from matplot_patient_trajectory import MatplotlibPatientTrajectoryMiddleChildhood
from allpackages import warnings, ast, os, pd, load_dotenv
import matplotlib.pyplot as plt

load_dotenv()

# Get SubsetDataset folder path from environment variables & read subset dataset CSV file
subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset = os.path.join(
    subset_dataset_folder, "SubDataset_MiddleChildhood_M_NoADHD.csv"
)
original_df = pd.read_csv(subset_dataset)

print(original_df["cluster"].value_counts())
# Create an instance of MatplotlibPatientTrajectory
patient_trajectory = MatplotlibPatientTrajectoryMiddleChildhood()

# Call the load_data method
processed_df = patient_trajectory.load_data(original_df)

# Select the first fifty patients based on their patient id
selected_patients = processed_df["pasient"].unique()[:50]

# Filter the episodes associated with the selected patients
processed_df = processed_df[processed_df["pasient"].isin(selected_patients)]

custom_colors = ["red", "green", "purple"]
unique_patients = processed_df["pasient"].unique()
fig, axes = plt.subplots(1, 1, figsize=(30, 14))
fig.suptitle(
    "Middle Childhood, Male, No ADHD patient  trajectory with age, count visit, cluster label, diagnosis and medication during each episode"
)
fig.tight_layout(pad=2)
patient_trajectory.patient_timeline_plot_yearly(
    processed_df, axes, custom_colors, unique_patients
)

fig.show()

FigureTrajectory_folder = os.getenv("FigureTrajectory")
fig.savefig(
    os.path.join(FigureTrajectory_folder, "MiddleChildhood_M_NoADHD.jpg"),
    dpi=300,
    bbox_inches="tight",
)

# %% [markdown]
# #### 7. Patient trajectory plot which satify this condition `Gender = F`, `AgeGroup = MiddleChildhood` and `ADHD = 1`

# %%
from matplot_patient_trajectory import MatplotlibPatientTrajectoryMiddleChildhood
from allpackages import warnings, ast, os, pd, load_dotenv
import matplotlib.pyplot as plt

load_dotenv()

# Get SubsetDataset folder path from environment variables & read subset dataset CSV file
subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset = os.path.join(
    subset_dataset_folder, "SubDataset_MiddleChildhood_F_ADHD.csv"
)
original_df = pd.read_csv(subset_dataset)

print(original_df["cluster"].value_counts())
# Create an instance of MatplotlibPatientTrajectoryMiddleChildhood
patient_trajectory = MatplotlibPatientTrajectoryMiddleChildhood()

# Call the load_data method
processed_df = patient_trajectory.load_data(original_df)

# Select the first fifty patients based on their patient id
selected_patients = processed_df["pasient"].unique()[:50]

# Filter the episodes associated with the selected patients
processed_df = processed_df[processed_df["pasient"].isin(selected_patients)]

custom_colors = ["red", "green", "purple"]
unique_patients = processed_df["pasient"].unique()
fig, axes = plt.subplots(1, 1, figsize=(30, 14))
fig.suptitle(
    "Middle Childhood, Female, ADHD patient  trajectory with age, count visit, cluster label, diagnosis and medication during each episode"
)
fig.tight_layout(pad=2)
patient_trajectory.patient_timeline_plot_yearly(
    processed_df, axes, custom_colors, unique_patients
)

fig.show()

FigureTrajectory_folder = os.getenv("FigureTrajectory")
fig.savefig(
    os.path.join(FigureTrajectory_folder, "MiddleChildhood_F_ADHD.jpg"),
    dpi=300,
    bbox_inches="tight",
)

# %% [markdown]
# #### 8. Patient trajectory plot which satify this condition `Gender = F`, `AgeGroup = MiddleChildhood` and `ADHD = 0`

# %%
from matplot_patient_trajectory import MatplotlibPatientTrajectoryMiddleChildhood
from allpackages import warnings, ast, os, pd, load_dotenv
import matplotlib.pyplot as plt

load_dotenv()

# Get SubsetDataset folder path from environment variables & read subset dataset CSV file
subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset = os.path.join(
    subset_dataset_folder, "SubDataset_MiddleChildhood_F_NoADHD.csv"
)
original_df = pd.read_csv(subset_dataset)

print(original_df["cluster"].value_counts())
# Create an instance of MatplotlibPatientTrajectoryMiddleChildhood
patient_trajectory = MatplotlibPatientTrajectoryMiddleChildhood()

# Call the load_data method
processed_df = patient_trajectory.load_data(original_df)

# Select the first fifty patients based on their patient id
selected_patients = processed_df["pasient"].unique()[:50]

# Filter the episodes associated with the selected patients
processed_df = processed_df[processed_df["pasient"].isin(selected_patients)]

custom_colors = ["red", "green", "purple"]
unique_patients = processed_df["pasient"].unique()
fig, axes = plt.subplots(1, 1, figsize=(30, 14))
fig.suptitle(
    "Middle Childhood, Female, No ADHD patient  trajectory with age, count visit, cluster label, diagnosis and medication during each episode"
)
fig.tight_layout(pad=2)
patient_trajectory.patient_timeline_plot_yearly(
    processed_df, axes, custom_colors, unique_patients
)

fig.show()

FigureTrajectory_folder = os.getenv("FigureTrajectory")
fig.savefig(
    os.path.join(FigureTrajectory_folder, "MiddleChildhood_F_NoADHD.jpg"),
    dpi=300,
    bbox_inches="tight",
)

# %% [markdown]
# #### 9. Patient trajectory plot which satify this condition `Gender = M`, `AgeGroup = Teenager` and `ADHD = 1`

# %%
from matplot_patient_trajectory import MatplotlibPatientTrajectoryTeenager
from allpackages import warnings, ast, os, pd, load_dotenv
import matplotlib.pyplot as plt

load_dotenv()

# Get SubsetDataset folder path from environment variables & read subset dataset CSV file
subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset = os.path.join(subset_dataset_folder, "SubDataset_Teenager_M_ADHD.csv")
original_df = pd.read_csv(subset_dataset)

print(original_df["cluster"].value_counts())
# Create an instance of MatplotlibPatientTrajectoryTeenager
patient_trajectory = MatplotlibPatientTrajectoryTeenager()

# Call the load_data method
processed_df = patient_trajectory.load_data(original_df)

# Select the first fifty patients based on their patient id
selected_patients = processed_df["pasient"].unique()[:50]

# Filter the episodes associated with the selected patients
processed_df = processed_df[processed_df["pasient"].isin(selected_patients)]

custom_colors = ["red", "green", "purple"]
unique_patients = processed_df["pasient"].unique()
fig, axes = plt.subplots(1, 1, figsize=(30, 14))
fig.suptitle(
    "Teenager, Male, ADHD patient  trajectory with age, count visit, cluster label, diagnosis and medication during each episode"
)
fig.tight_layout(pad=2)
patient_trajectory.patient_timeline_plot_yearly(
    processed_df, axes, custom_colors, unique_patients
)
fig.show()

FigureTrajectory_folder = os.getenv("FigureTrajectory")
fig.savefig(
    os.path.join(FigureTrajectory_folder, "Teenager_M_ADHD.jpg"),
    dpi=300,
    bbox_inches="tight",
)

# %% [markdown]
# #### 10. Patient trajectory plot which satify this condition `Gender = M`, `AgeGroup = Teenager` and `ADHD = 0`

# %%
from matplot_patient_trajectory import MatplotlibPatientTrajectoryTeenager
from allpackages import warnings, ast, os, pd, load_dotenv
import matplotlib.pyplot as plt

load_dotenv()

# Get SubsetDataset folder path from environment variables & read subset dataset CSV file
subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset = os.path.join(subset_dataset_folder, "SubDataset_Teenager_M_NoADHD.csv")
original_df = pd.read_csv(subset_dataset)

print(original_df["cluster"].value_counts())
# Create an instance of MatplotlibPatientTrajectoryTeenager
patient_trajectory = MatplotlibPatientTrajectoryTeenager()

# Call the load_data method
processed_df = patient_trajectory.load_data(original_df)

# Select the first fifty patients based on their patient id
selected_patients = processed_df["pasient"].unique()[:50]

# Filter the episodes associated with the selected patients
processed_df = processed_df[processed_df["pasient"].isin(selected_patients)]

custom_colors = ["red", "green", "purple"]
unique_patients = processed_df["pasient"].unique()
fig, axes = plt.subplots(1, 1, figsize=(30, 14))
fig.suptitle(
    "Teenager, Male, No ADHD patient  trajectory with age, count visit, cluster label, diagnosis and medication during each episode"
)
fig.tight_layout(pad=2)
patient_trajectory.patient_timeline_plot_yearly(
    processed_df, axes, custom_colors, unique_patients
)

fig.show()

FigureTrajectory_folder = os.getenv("FigureTrajectory")
fig.savefig(
    os.path.join(FigureTrajectory_folder, "Teenager_M_NoADHD.jpg"),
    dpi=300,
    bbox_inches="tight",
)

# %% [markdown]
# #### 11. Patient trajectory plot which satify this condition `Gender = F`, `AgeGroup = Teenager` and `ADHD = 1`

# %%
from matplot_patient_trajectory import MatplotlibPatientTrajectoryTeenager
from allpackages import warnings, ast, os, pd, load_dotenv
import matplotlib.pyplot as plt

load_dotenv()

# Get SubsetDataset folder path from environment variables & read subset dataset CSV file
subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset = os.path.join(subset_dataset_folder, "SubDataset_Teenager_F_ADHD.csv")
original_df = pd.read_csv(subset_dataset)

print(original_df["cluster"].value_counts())
# Create an instance of MatplotlibPatientTrajectoryTeenager
patient_trajectory = MatplotlibPatientTrajectoryTeenager()

# Call the load_data method
processed_df = patient_trajectory.load_data(original_df)

# Select the first fifty patients based on their patient id
selected_patients = processed_df["pasient"].unique()[:50]

# Filter the episodes associated with the selected patients
processed_df = processed_df[processed_df["pasient"].isin(selected_patients)]

custom_colors = ["red", "green", "purple"]
unique_patients = processed_df["pasient"].unique()
fig, axes = plt.subplots(1, 1, figsize=(30, 14))
fig.suptitle(
    "Teenager, Female, ADHD patient  trajectory with age, count visit, cluster label, diagnosis and medication during each episode"
)
fig.tight_layout(pad=2)
patient_trajectory.patient_timeline_plot_yearly(
    processed_df, axes, custom_colors, unique_patients
)
fig.show()

FigureTrajectory_folder = os.getenv("FigureTrajectory")
fig.savefig(
    os.path.join(FigureTrajectory_folder, "Teenager_F_ADHD.jpg"),
    dpi=300,
    bbox_inches="tight",
)

# %% [markdown]
# #### 12. Patient trajectory plot which satify this condition `Gender = F`, `AgeGroup = Teenager` and `ADHD = 0`

# %%
from matplot_patient_trajectory import MatplotlibPatientTrajectoryTeenager
from allpackages import warnings, ast, os, pd, load_dotenv
import matplotlib.pyplot as plt

load_dotenv()

# Get SubsetDataset folder path from environment variables & read subset dataset CSV file
subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset = os.path.join(subset_dataset_folder, "SubDataset_Teenager_F_NoADHD.csv")
original_df = pd.read_csv(subset_dataset)

print(original_df["cluster"].value_counts())
# Create an instance of MatplotlibPatientTrajectoryTeenager
patient_trajectory = MatplotlibPatientTrajectoryTeenager()

# Call the load_data method
processed_df = patient_trajectory.load_data(original_df)

# Select the first fifty patients based on their patient id
selected_patients = processed_df["pasient"].unique()[:50]

# Filter the episodes associated with the selected patients
processed_df = processed_df[processed_df["pasient"].isin(selected_patients)]

custom_colors = ["red", "green", "purple"]
unique_patients = processed_df["pasient"].unique()
fig, axes = plt.subplots(1, 1, figsize=(30, 14))
fig.suptitle(
    "Teenager, Female, No ADHD patient  trajectory with age, count visit, cluster label, diagnosis and medication during each episode"
)
fig.tight_layout(pad=2)
patient_trajectory.patient_timeline_plot_yearly(
    processed_df, axes, custom_colors, unique_patients
)

fig.show()

FigureTrajectory_folder = os.getenv("FigureTrajectory")
fig.savefig(
    os.path.join(FigureTrajectory_folder, "Teenager_F_NoADHD.jpg"),
    dpi=300,
    bbox_inches="tight",
)

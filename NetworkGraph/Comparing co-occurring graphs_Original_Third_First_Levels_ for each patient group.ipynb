# %% [markdown]
# ### The 6 possible combinations from the 12 total combinations which ADHD=1 for AgeGroup = ["Preschooler", "MiddelSchool", "Teenager"] || Gender = ["M", "F"] are:
#
# 1. Preschooler, Male, ADHD: (Preschooler, M, 1)
#
# 3. Preschooler, Female, ADHD: (Preschooler, F, 1)
#
# 5. MiddelChildhood, Male, ADHD: (MiddelChildhood, M, 1)
#
#
# 7. MiddelChildhood, Female, ADHD: (MiddelChildhood, F, 1)
#
# 9. Teenager, Male, ADHD: (Teenager, M, 1)
#
# 11. Teenager, Female, ADHD: (Teenager, F, 1)

# %% [markdown]
# # Comparing F90 Co-occurring graphs in Adjusted Original level, level 3 and level 1 for each patient group

# %%
from allpackages import warnings, ast, os, nx, pd, plt, Image, load_dotenv

from network_graph_backend import CoocurringDiagnosisNetworkGraph_adjusted
from network_graph_backend import CoocurringDiagnosisNetworkGraph_higherlevel31
from network_graph_backend import CoocurringDiagnosisNetworkGraph_higherlevel11

# %%
# For PreSchooler_F_ADHD
#########################################################################################################
subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset_path = os.path.join(subset_dataset_folder, "SubDataset_PreSchooler_F_ADHD.csv")
original_df = pd.read_csv(subset_dataset_path)
print(original_df.shape)

# Create a 1x4 subplot grid
fig, axs = plt.subplots(1, 3, figsize=(20, 5))


# Plot 1
network_graph2 = CoocurringDiagnosisNetworkGraph_adjusted()
nwg2=network_graph2.load_plot_network_graph(original_df)
FigureGraph_folder = os.getenv("save_path")
nwg2.savefig(os.path.join(FigureGraph_folder, "PreSchooler_F_ADHD_plot1.jpg"), bbox_inches="tight")

# Plot 2
network_graph3 = CoocurringDiagnosisNetworkGraph_higherlevel31()
nwg3=network_graph3.load_plot_network_graph(original_df)
FigureGraph_folder = os.getenv("save_path")
nwg3.savefig(os.path.join(FigureGraph_folder, "PreSchooler_F_ADHD_plot2.jpg"), bbox_inches="tight")

# Plot 3
network_graph4 = CoocurringDiagnosisNetworkGraph_higherlevel11()
nwg4=network_graph4.load_plot_network_graph(original_df)
FigureGraph_folder = os.getenv("save_path")
nwg4.savefig(os.path.join(FigureGraph_folder, "PreSchooler_F_ADHD_plot3.jpg"), bbox_inches="tight")

# Load and display each image on the subplot grid
for i, plot_filename in enumerate(["PreSchooler_F_ADHD_plot1.jpg", "PreSchooler_F_ADHD_plot2.jpg", "PreSchooler_F_ADHD_plot3.jpg"]):
    img_path = os.path.join(FigureGraph_folder, plot_filename)
    img = Image.open(img_path)
    axs[i].imshow(img)
    axs[i].axis('off')
    axs[0].set_title("Original Level", fontsize = 18)
    axs[1].set_title("Level 3", fontsize = 18)
    axs[2].set_title("Level 1", fontsize = 18)


plt.tight_layout()

# Save the entire figure containing the subplot grid to a file
output_filename = "PreSchooler_F_ADHD_combined_network_graphs.eps"  
output_path = os.path.join(FigureGraph_folder, output_filename)
fig.savefig(output_path, bbox_inches="tight", dpi=300)


output_filename = "PreSchooler_F_ADHD_combined_network_graphs.jpg"  
output_path = os.path.join(FigureGraph_folder, output_filename)
fig.savefig(output_path, bbox_inches="tight", dpi=300)
fig.show()  # Show the plot grid

# %%
# For PreSchooler_M_ADHD
#########################################################################################################
subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset_path = os.path.join(subset_dataset_folder, "SubDataset_PreSchooler_M_ADHD.csv")
original_df = pd.read_csv(subset_dataset_path)
print(original_df.shape)

# Create a 1x4 subplot grid
fig, axs = plt.subplots(1, 3, figsize=(20, 5))


# Plot 1
network_graph2 = CoocurringDiagnosisNetworkGraph_adjusted()
nwg2=network_graph2.load_plot_network_graph(original_df)
FigureGraph_folder = os.getenv("save_path")
nwg2.savefig(os.path.join(FigureGraph_folder, "PreSchooler_M_ADHD_plot1.jpg"), bbox_inches="tight")

# Plot 2
network_graph3 = CoocurringDiagnosisNetworkGraph_higherlevel31()
nwg3=network_graph3.load_plot_network_graph(original_df)
FigureGraph_folder = os.getenv("save_path")
nwg3.savefig(os.path.join(FigureGraph_folder, "PreSchooler_M_ADHD_plot2.jpg"), bbox_inches="tight")

# Plot 3
network_graph4 = CoocurringDiagnosisNetworkGraph_higherlevel11()
nwg4=network_graph4.load_plot_network_graph(original_df)
FigureGraph_folder = os.getenv("save_path")
nwg4.savefig(os.path.join(FigureGraph_folder, "PreSchooler_M_ADHD_plot3.jpg"), bbox_inches="tight")

# Load and display each image on the subplot grid
for i, plot_filename in enumerate(["PreSchooler_M_ADHD_plot1.jpg", "PreSchooler_M_ADHD_plot2.jpg", "PreSchooler_M_ADHD_plot3.jpg"]):
    img_path = os.path.join(FigureGraph_folder, plot_filename)
    img = Image.open(img_path)
    axs[i].imshow(img)
    axs[i].axis('off')
    axs[0].set_title("Original Level", fontsize = 18)
    axs[1].set_title("Level 3", fontsize = 18)
    axs[2].set_title("Level 1", fontsize = 18)


plt.tight_layout()

# Save the entire figure containing the subplot grid to a file
output_filename = "PreSchooler_M_ADHD_combined_network_graphs.eps"  
output_path = os.path.join(FigureGraph_folder, output_filename)
fig.savefig(output_path, bbox_inches="tight", dpi=300)


output_filename = "PreSchooler_M_ADHD_combined_network_graphs.jpg"  
output_path = os.path.join(FigureGraph_folder, output_filename)
fig.savefig(output_path, bbox_inches="tight", dpi=300)
fig.show()  # Show the plot grid

# %%
# For MiddelChildhood_F_ADHD
#########################################################################################################
subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset_path = os.path.join(subset_dataset_folder, "SubDataset_MiddelChildhood_F_ADHD.csv")
original_df = pd.read_csv(subset_dataset_path)
print(original_df.shape)

# Create a 1x4 subplot grid
fig, axs = plt.subplots(1, 3, figsize=(35, 35))
plt.subplots_adjust(hspace=0.000001)
plt.subplots_adjust(wspace=0.000001) 

# Plot 1
network_graph2 = CoocurringDiagnosisNetworkGraph_adjusted()
nwg2=network_graph2.load_plot_network_graph(original_df)
FigureGraph_folder = os.getenv("save_path")
nwg2.savefig(os.path.join(FigureGraph_folder, "MiddelChildhood_F_ADHD_plot1.jpg"), bbox_inches="tight")

# Plot 2
network_graph3 = CoocurringDiagnosisNetworkGraph_higherlevel31()
nwg3=network_graph3.load_plot_network_graph(original_df)
FigureGraph_folder = os.getenv("save_path")
nwg3.savefig(os.path.join(FigureGraph_folder, "MiddelChildhood_F_ADHD_plot2.jpg"), bbox_inches="tight")

# Plot 3
network_graph4 = CoocurringDiagnosisNetworkGraph_higherlevel11()
nwg4=network_graph4.load_plot_network_graph(original_df)
FigureGraph_folder = os.getenv("save_path")
nwg4.savefig(os.path.join(FigureGraph_folder, "MiddelChildhood_F_ADHD_plot3.jpg"), bbox_inches="tight")

# Load and display each image on the subplot grid
for i, plot_filename in enumerate(["MiddelChildhood_F_ADHD_plot1.jpg", "MiddelChildhood_F_ADHD_plot2.jpg", "MiddelChildhood_F_ADHD_plot3.jpg"]):
    img_path = os.path.join(FigureGraph_folder, plot_filename)
    img = Image.open(img_path)
    axs[0].set_title("Original Level", fontsize = 18)
    axs[1].set_title("Level 3", fontsize = 18)
    axs[2].set_title("Level 1", fontsize = 18)
    axs[i].imshow(img)
    axs[i].axis('off')    


# plt.tight_layout()


# Save the entire figure containing the subplot grid to a file
output_filename = "MiddelChildhood_F_ADHD_combined_network_graphs.eps"  
output_path = os.path.join(FigureGraph_folder, output_filename)
fig.savefig(output_path, bbox_inches="tight", dpi=190)

output_filename = "MiddelChildhood_F_ADHD_combined_network_graphs.jpg"  
output_path = os.path.join(FigureGraph_folder, output_filename)
fig.savefig(output_path, bbox_inches="tight", dpi=300)

fig.show()  # Show the plot grid
buf = io.BytesIO()
fig.savefig(buf, format='png')
buf.seek(0)  # Seek to the start of the BytesIO object
size_in_bytes = len(buf.getvalue())

# Convert bytes to megabytes
size_in_megabytes = size_in_bytes / (1024 * 1024)
print(f"The figure size is approximately {size_in_megabytes:.2f} MB")

# %%
# For MiddelChildhood_M_ADHD
#########################################################################################################
subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset_path = os.path.join(subset_dataset_folder, "SubDataset_MiddelChildhood_M_ADHD.csv")
original_df = pd.read_csv(subset_dataset_path)
print(original_df.shape)

# Create a 1x4 subplot grid
fig, axs = plt.subplots(1, 3, figsize=(20, 5))


# Plot 1
network_graph2 = CoocurringDiagnosisNetworkGraph_adjusted()
nwg2=network_graph2.load_plot_network_graph(original_df)
FigureGraph_folder = os.getenv("save_path")
nwg2.savefig(os.path.join(FigureGraph_folder, "MiddelChildhood_M_ADHD_plot1.jpg"), bbox_inches="tight")

# Plot 2
network_graph3 = CoocurringDiagnosisNetworkGraph_higherlevel31()
nwg3=network_graph3.load_plot_network_graph(original_df)
FigureGraph_folder = os.getenv("save_path")
nwg3.savefig(os.path.join(FigureGraph_folder, "MiddelChildhood_M_ADHD_plot2.jpg"), bbox_inches="tight")

# Plot 3
network_graph4 = CoocurringDiagnosisNetworkGraph_higherlevel11()
nwg4=network_graph4.load_plot_network_graph(original_df)
FigureGraph_folder = os.getenv("save_path")
nwg4.savefig(os.path.join(FigureGraph_folder, "MiddelChildhood_M_ADHD_plot3.jpg"), bbox_inches="tight")

# Load and display each image on the subplot grid
for i, plot_filename in enumerate(["MiddelChildhood_M_ADHD_plot1.jpg", "MiddelChildhood_M_ADHD_plot2.jpg", "MiddelChildhood_M_ADHD_plot3.jpg"]):
    img_path = os.path.join(FigureGraph_folder, plot_filename)
    img = Image.open(img_path)
    axs[i].imshow(img)
    axs[i].axis('off')  
    axs[0].set_title("Original Level", fontsize = 18)
    axs[1].set_title("Level 3", fontsize = 18)
    axs[2].set_title("Level 1", fontsize = 18)

plt.tight_layout()

# Save the entire figure containing the subplot grid to a file
output_filename = "MiddelChildhood_M_ADHD_combined_network_graphs.eps"  
output_path = os.path.join(FigureGraph_folder, output_filename)
fig.savefig(output_path, bbox_inches="tight", dpi=300)

output_filename = "MiddelChildhood_M_ADHD_combined_network_graphs.jpg"  
output_path = os.path.join(FigureGraph_folder, output_filename)
fig.savefig(output_path, bbox_inches="tight", dpi=300)
fig.show()  # Show the plot grid

# %%
# For Teenager_F_ADHD
#########################################################################################################
subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset_path = os.path.join(subset_dataset_folder, "SubDataset_Teenager_F_ADHD.csv")
original_df = pd.read_csv(subset_dataset_path)
print(original_df.shape)

# Create a 1x4 subplot grid
fig, axs = plt.subplots(1, 3, figsize=(20, 5))


# Plot 1
network_graph2 = CoocurringDiagnosisNetworkGraph_adjusted()
nwg2=network_graph2.load_plot_network_graph(original_df)
FigureGraph_folder = os.getenv("save_path")
nwg2.savefig(os.path.join(FigureGraph_folder, "Teenager_F_ADHD_plot1.jpg"), bbox_inches="tight")

# Plot 2
network_graph3 = CoocurringDiagnosisNetworkGraph_higherlevel31()
nwg3=network_graph3.load_plot_network_graph(original_df)
FigureGraph_folder = os.getenv("save_path")
nwg3.savefig(os.path.join(FigureGraph_folder, "Teenager_F_ADHD_plot2.jpg"), bbox_inches="tight")

# Plot 3
network_graph4 = CoocurringDiagnosisNetworkGraph_higherlevel11()
nwg4=network_graph4.load_plot_network_graph(original_df)
FigureGraph_folder = os.getenv("save_path")
nwg4.savefig(os.path.join(FigureGraph_folder, "Teenager_F_ADHD_plot3.jpg"), bbox_inches="tight")

# Load and display each image on the subplot grid
for i, plot_filename in enumerate(["Teenager_F_ADHD_plot1.jpg", "Teenager_F_ADHD_plot2.jpg", "Teenager_F_ADHD_plot3.jpg"]):
    img_path = os.path.join(FigureGraph_folder, plot_filename)
    img = Image.open(img_path)
    axs[i].imshow(img)
    axs[i].axis('off')  
    axs[0].set_title("Original Level", fontsize = 18)
    axs[1].set_title("Level 3", fontsize = 18)
    axs[2].set_title("Level 1", fontsize = 18)

plt.tight_layout()

# Save the entire figure containing the subplot grid to a file
output_filename = "Teenager_F_ADHD_combined_network_graphs.eps"  
output_path = os.path.join(FigureGraph_folder, output_filename)
fig.savefig(output_path, bbox_inches="tight", dpi=300)

output_filename = "Teenager_F_ADHD_combined_network_graphs.jpg"  
output_path = os.path.join(FigureGraph_folder, output_filename)
fig.savefig(output_path, bbox_inches="tight", dpi=300)

fig.show()  # Show the plot grid

# %%
# For Teenager_M_ADHD
#########################################################################################################
subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset_path = os.path.join(subset_dataset_folder, "SubDataset_Teenager_M_ADHD.csv")
original_df = pd.read_csv(subset_dataset_path)
print(original_df.shape)

# Create a 1x3 subplot grid
fig, axs = plt.subplots(1, 3, figsize=(20, 5))


# Plot 1
network_graph2 = CoocurringDiagnosisNetworkGraph_adjusted()
nwg2=network_graph2.load_plot_network_graph(original_df)
FigureGraph_folder = os.getenv("save_path")
nwg2.savefig(os.path.join(FigureGraph_folder, "Teenager_M_ADHD_plot1.jpg"), bbox_inches="tight")

# Plot 2
network_graph3 = CoocurringDiagnosisNetworkGraph_higherlevel31()
nwg3=network_graph3.load_plot_network_graph(original_df)
FigureGraph_folder = os.getenv("save_path")
nwg3.savefig(os.path.join(FigureGraph_folder, "Teenager_M_ADHD_plot2.jpg"), bbox_inches="tight")

# Plot 3
network_graph4 = CoocurringDiagnosisNetworkGraph_higherlevel11()
nwg4=network_graph4.load_plot_network_graph(original_df)
FigureGraph_folder = os.getenv("save_path")
nwg4.savefig(os.path.join(FigureGraph_folder, "Teenager_M_ADHD_plot3.jpg"), bbox_inches="tight")

# Load and display each image on the subplot grid
for i, plot_filename in enumerate(["Teenager_M_ADHD_plot1.jpg", "Teenager_M_ADHD_plot2.jpg", "Teenager_M_ADHD_plot3.jpg"]):
    img_path = os.path.join(FigureGraph_folder, plot_filename)
    img = Image.open(img_path)
    axs[i].imshow(img)
    axs[i].axis('off')  
    axs[0].set_title("Original Level", fontsize = 18)
    axs[1].set_title("Level 3", fontsize = 18)
    axs[2].set_title("Level 1", fontsize = 18)

plt.tight_layout()

# Save the entire figure containing the subplot grid to a file
output_filename = "Teenager_M_ADHD_combined_network_graphs.eps"  
output_path = os.path.join(FigureGraph_folder, output_filename)
fig.savefig(output_path, bbox_inches="tight", dpi=300)

output_filename = "Teenager_M_ADHD_combined_network_graphs.jpg"  
output_path = os.path.join(FigureGraph_folder, output_filename)
fig.savefig(output_path, bbox_inches="tight", dpi=300)

fig.show()  # Show the plot grid

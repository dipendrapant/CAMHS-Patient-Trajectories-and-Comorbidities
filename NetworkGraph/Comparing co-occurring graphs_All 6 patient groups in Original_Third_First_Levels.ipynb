# %% [markdown]
# ### The 6 possible combinations from the 12 total combinations which ADHD=1 for AgeGroup = ["Preschooler", "MiddleSchool", "Teenager"] || Gender = ["M", "F"] are:
#
# 1. Preschooler, Male, ADHD: (Preschooler, M, 1)
#
# 3. Preschooler, Female, ADHD: (Preschooler, F, 1)
#
# 5. MiddleChildhood, Male, ADHD: (MiddleChildhood, M, 1)
#
#
# 7. MiddleChildhood, Female, ADHD: (MiddleChildhood, F, 1)
#
# 9. Teenager, Male, ADHD: (Teenager, M, 1)
#
# 11. Teenager, Female, ADHD: (Teenager, F, 1)

# %% [markdown]
# # Comparing F90 Co-occurring graphs of all 6 patient groups with ADHD in all Adjusted Original level, level 3 and level 1

# %%
from allpackages import warnings, ast, os, nx, pd, plt, Image, load_dotenv

from network_graph_backend import CoocurringDiagnosisNetworkGraph_adjusted
from network_graph_backend import CoocurringDiagnosisNetworkGraph_higherlevel31
from network_graph_backend import CoocurringDiagnosisNetworkGraph_higherlevel11

# %%
# For Adjusted Original_level
#########################################################################################################
subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset_path = os.path.join(subset_dataset_folder, "SubDataset_PreSchooler_F_ADHD.csv")
original_df1 = pd.read_csv(subset_dataset_path)
# print(original_df1.shape)

subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset_path = os.path.join(subset_dataset_folder, "SubDataset_PreSchooler_M_ADHD.csv")
original_df2 = pd.read_csv(subset_dataset_path)
# print(original_df2.shape)

subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset_path = os.path.join(subset_dataset_folder, "SubDataset_MiddelChildhood_F_ADHD.csv")
original_df3= pd.read_csv(subset_dataset_path)
# print(original_df3.shape)

subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset_path = os.path.join(subset_dataset_folder, "SubDataset_MiddelChildhood_M_ADHD.csv")
original_df4 = pd.read_csv(subset_dataset_path)
# print(original_df4.shape)

subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset_path = os.path.join(subset_dataset_folder, "SubDataset_Teenager_F_ADHD.csv")
original_df5 = pd.read_csv(subset_dataset_path)
# print(original_df5.shape)

subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset_path = os.path.join(subset_dataset_folder, "SubDataset_Teenager_M_ADHD.csv")
original_df6 = pd.read_csv(subset_dataset_path)
# print(original_df6.shape)

# Create a 2x3 subplot grid
fig, axs = plt.subplots(2, 3, figsize=(20, 15))
plt.subplots_adjust(hspace=0.01)

# Plot 1
network_graph2 = CoocurringDiagnosisNetworkGraph_adjusted()
nwg1=network_graph2.load_plot_network_graph(original_df1)
FigureGraph_folder = os.getenv("save_path")
nwg1.savefig(os.path.join(FigureGraph_folder, "PreSchooler_F_ADHD.jpg"), bbox_inches="tight")



# Plot 2
network_graph2 = CoocurringDiagnosisNetworkGraph_adjusted()
nwg2=network_graph2.load_plot_network_graph(original_df2)
FigureGraph_folder = os.getenv("save_path")
nwg2.savefig(os.path.join(FigureGraph_folder, "PreSchooler_M_ADHD.jpg"), bbox_inches="tight")


# Plot 3
network_graph2 = CoocurringDiagnosisNetworkGraph_adjusted()
nwg3=network_graph2.load_plot_network_graph(original_df3)
FigureGraph_folder = os.getenv("save_path")
nwg3.savefig(os.path.join(FigureGraph_folder, "MiddelChildhood_F_ADHD.jpg"), bbox_inches="tight")


# Plot 4
network_graph2 = CoocurringDiagnosisNetworkGraph_adjusted()
nwg4=network_graph2.load_plot_network_graph(original_df4)
FigureGraph_folder = os.getenv("save_path")
nwg4.savefig(os.path.join(FigureGraph_folder, "MiddelChildhood_M_ADHD.jpg"), bbox_inches="tight")


# Plot 5
network_graph2 = CoocurringDiagnosisNetworkGraph_adjusted()
nwg5=network_graph2.load_plot_network_graph(original_df5)
FigureGraph_folder = os.getenv("save_path")
nwg5.savefig(os.path.join(FigureGraph_folder, "Teenager_F_ADHD.jpg"), bbox_inches="tight")



# Plot 6
network_graph2 = CoocurringDiagnosisNetworkGraph_adjusted()
nwg6=network_graph2.load_plot_network_graph(original_df6)
FigureGraph_folder = os.getenv("save_path")
nwg6.savefig(os.path.join(FigureGraph_folder, "Teenager_M_ADHD.jpg"), bbox_inches="tight")

# Load and display each image on the subplot grid
for i, plot_filename in enumerate(["PreSchooler_F_ADHD.jpg", "MiddelChildhood_F_ADHD.jpg", "Teenager_F_ADHD.jpg", "PreSchooler_M_ADHD.jpg", "MiddelChildhood_M_ADHD.jpg", "Teenager_M_ADHD.jpg"]):
    img_path = os.path.join(FigureGraph_folder, plot_filename)
    img = Image.open(img_path)
    row = i // 3  # Integer division to get row index
    col = i % 3  # Remainder to get column index
    axs[row, col].set_title(plot_filename[:-4])
    axs[row, col].imshow(img)
    axs[row, col].axis('off')  


plt.tight_layout()

# Save the entire figure containing the subplot grid to a file
output_filename = "combined_original_adjusted_network_graphs.eps"  
output_path = os.path.join(FigureGraph_folder, output_filename)
fig.savefig(output_path, bbox_inches="tight", dpi=300)


output_filename = "combined_original_adjusted_network_graphs.jpg"  
output_path = os.path.join(FigureGraph_folder, output_filename)
fig.savefig(output_path, bbox_inches="tight", dpi=300)

fig.show()

# %%
# For Level 3
#########################################################################################################
subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset_path = os.path.join(subset_dataset_folder, "SubDataset_PreSchooler_F_ADHD.csv")
original_df1 = pd.read_csv(subset_dataset_path)
# print(original_df1.shape)

subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset_path = os.path.join(subset_dataset_folder, "SubDataset_PreSchooler_M_ADHD.csv")
original_df2 = pd.read_csv(subset_dataset_path)
# print(original_df2.shape)

subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset_path = os.path.join(subset_dataset_folder, "SubDataset_MiddelChildhood_F_ADHD.csv")
original_df3= pd.read_csv(subset_dataset_path)
# print(original_df3.shape)

subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset_path = os.path.join(subset_dataset_folder, "SubDataset_MiddelChildhood_M_ADHD.csv")
original_df4 = pd.read_csv(subset_dataset_path)
# print(original_df4.shape)

subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset_path = os.path.join(subset_dataset_folder, "SubDataset_Teenager_F_ADHD.csv")
original_df5 = pd.read_csv(subset_dataset_path)
# print(original_df5.shape)

subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset_path = os.path.join(subset_dataset_folder, "SubDataset_Teenager_M_ADHD.csv")
original_df6 = pd.read_csv(subset_dataset_path)
# print(original_df6.shape)

# Create a 2x3 subplot grid
fig, axs = plt.subplots(2, 3, figsize=(20, 15))
plt.subplots_adjust(hspace=0.01)
plt.subplots_adjust(wspace=0.01)

# Plot 1
network_graph2 = CoocurringDiagnosisNetworkGraph_higherlevel31()
nwg1=network_graph2.load_plot_network_graph(original_df1)
FigureGraph_folder = os.getenv("save_path")
nwg1.savefig(os.path.join(FigureGraph_folder, "PreSchooler_F_ADHD.jpg"), bbox_inches="tight")



# Plot 2
network_graph2 = CoocurringDiagnosisNetworkGraph_higherlevel31()
nwg2=network_graph2.load_plot_network_graph(original_df2)
FigureGraph_folder = os.getenv("save_path")
nwg2.savefig(os.path.join(FigureGraph_folder, "PreSchooler_M_ADHD.jpg"), bbox_inches="tight")


# Plot 3
network_graph2 = CoocurringDiagnosisNetworkGraph_higherlevel31()
nwg3=network_graph2.load_plot_network_graph(original_df3)
FigureGraph_folder = os.getenv("save_path")
nwg3.savefig(os.path.join(FigureGraph_folder, "MiddelChildhood_F_ADHD.jpg"), bbox_inches="tight")


# Plot 4
network_graph2 = CoocurringDiagnosisNetworkGraph_higherlevel31()
nwg4=network_graph2.load_plot_network_graph(original_df4)
FigureGraph_folder = os.getenv("save_path")
nwg4.savefig(os.path.join(FigureGraph_folder, "MiddelChildhood_M_ADHD.jpg"), bbox_inches="tight")


# Plot 5
network_graph2 = CoocurringDiagnosisNetworkGraph_higherlevel31()
nwg5=network_graph2.load_plot_network_graph(original_df5)
FigureGraph_folder = os.getenv("save_path")
nwg5.savefig(os.path.join(FigureGraph_folder, "Teenager_F_ADHD.jpg"), bbox_inches="tight")



# Plot 6
network_graph2 = CoocurringDiagnosisNetworkGraph_higherlevel31()
nwg6=network_graph2.load_plot_network_graph(original_df6)
FigureGraph_folder = os.getenv("save_path")
nwg6.savefig(os.path.join(FigureGraph_folder, "Teenager_M_ADHD.jpg"), bbox_inches="tight")

# Load and display each image on the subplot grid
for i, plot_filename in enumerate(["PreSchooler_F_ADHD.jpg", "MiddelChildhood_F_ADHD.jpg", "Teenager_F_ADHD.jpg", "PreSchooler_M_ADHD.jpg", "MiddelChildhood_M_ADHD.jpg", "Teenager_M_ADHD.jpg"]):
    img_path = os.path.join(FigureGraph_folder, plot_filename)
    img = Image.open(img_path)
    row = i // 3  # Integer division to get row index
    col = i % 3  # Remainder to get column index
    axs[row, col].set_title(plot_filename[:-4])
    axs[row, col].imshow(img)
    axs[row, col].axis('off')  


plt.tight_layout()

# Save the entire figure containing the subplot grid to a file
output_filename = "combined_level3_network_graphs.eps"  
output_path = os.path.join(FigureGraph_folder, output_filename)
fig.savefig(output_path, bbox_inches="tight", dpi=225)


output_filename = "combined_level3_network_graphs.jpg"  
output_path = os.path.join(FigureGraph_folder, output_filename)
fig.savefig(output_path, bbox_inches="tight", dpi=225)

fig.show()

# %%
# For level 1
#########################################################################################################
subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset_path = os.path.join(subset_dataset_folder, "SubDataset_PreSchooler_F_ADHD.csv")
original_df1 = pd.read_csv(subset_dataset_path)
# print(original_df1.shape)

subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset_path = os.path.join(subset_dataset_folder, "SubDataset_PreSchooler_M_ADHD.csv")
original_df2 = pd.read_csv(subset_dataset_path)
# print(original_df2.shape)

subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset_path = os.path.join(subset_dataset_folder, "SubDataset_MiddelChildhood_F_ADHD.csv")
original_df3= pd.read_csv(subset_dataset_path)
# print(original_df3.shape)

subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset_path = os.path.join(subset_dataset_folder, "SubDataset_MiddelChildhood_M_ADHD.csv")
original_df4 = pd.read_csv(subset_dataset_path)
# print(original_df4.shape)

subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset_path = os.path.join(subset_dataset_folder, "SubDataset_Teenager_F_ADHD.csv")
original_df5 = pd.read_csv(subset_dataset_path)
# print(original_df5.shape)

subset_dataset_folder = os.getenv("SubsetDataset")
subset_dataset_path = os.path.join(subset_dataset_folder, "SubDataset_Teenager_M_ADHD.csv")
original_df6 = pd.read_csv(subset_dataset_path)
# print(original_df6.shape)

# Create a 2x3 subplot grid
fig, axs = plt.subplots(2, 3, figsize=(20, 15))
plt.subplots_adjust(hspace=0.01)
plt.subplots_adjust(wspace=0.01)

# Plot 1
network_graph2 = CoocurringDiagnosisNetworkGraph_higherlevel11()
nwg1=network_graph2.load_plot_network_graph(original_df1)
FigureGraph_folder = os.getenv("save_path")
nwg1.savefig(os.path.join(FigureGraph_folder, "PreSchooler_F_ADHD.jpg"), bbox_inches="tight")



# Plot 2
network_graph2 = CoocurringDiagnosisNetworkGraph_higherlevel11()
nwg2=network_graph2.load_plot_network_graph(original_df2)
FigureGraph_folder = os.getenv("save_path")
nwg2.savefig(os.path.join(FigureGraph_folder, "PreSchooler_M_ADHD.jpg"), bbox_inches="tight")


# Plot 3
network_graph2 = CoocurringDiagnosisNetworkGraph_higherlevel11()
nwg3=network_graph2.load_plot_network_graph(original_df3)
FigureGraph_folder = os.getenv("save_path")
nwg3.savefig(os.path.join(FigureGraph_folder, "MiddelChildhood_F_ADHD.jpg"), bbox_inches="tight")


# Plot 4
network_graph2 = CoocurringDiagnosisNetworkGraph_higherlevel11()
nwg4=network_graph2.load_plot_network_graph(original_df4)
FigureGraph_folder = os.getenv("save_path")
nwg4.savefig(os.path.join(FigureGraph_folder, "MiddelChildhood_M_ADHD.jpg"), bbox_inches="tight")


# Plot 5
network_graph2 = CoocurringDiagnosisNetworkGraph_higherlevel11()
nwg5=network_graph2.load_plot_network_graph(original_df5)
FigureGraph_folder = os.getenv("save_path")
nwg5.savefig(os.path.join(FigureGraph_folder, "Teenager_F_ADHD.jpg"), bbox_inches="tight")



# Plot 6
network_graph2 = CoocurringDiagnosisNetworkGraph_higherlevel11()
nwg6=network_graph2.load_plot_network_graph(original_df6)
FigureGraph_folder = os.getenv("save_path")
nwg6.savefig(os.path.join(FigureGraph_folder, "Teenager_M_ADHD.jpg"), bbox_inches="tight")

# Load and display each image on the subplot grid
for i, plot_filename in enumerate(["PreSchooler_F_ADHD.jpg", "MiddelChildhood_F_ADHD.jpg", "Teenager_F_ADHD.jpg", "PreSchooler_M_ADHD.jpg", "MiddelChildhood_M_ADHD.jpg", "Teenager_M_ADHD.jpg"]):
    img_path = os.path.join(FigureGraph_folder, plot_filename)
    img = Image.open(img_path)
    row = i // 3  # Integer division to get row index
    col = i % 3  # Remainder to get column index
    axs[row, col].set_title(plot_filename[:-4])
    axs[row, col].imshow(img)
    axs[row, col].axis('off')  


plt.tight_layout()

# Save the entire figure containing the subplot grid to a file
output_filename = "combined_level1_network_graphs.eps"  
output_path = os.path.join(FigureGraph_folder, output_filename)
fig.savefig(output_path, bbox_inches="tight", dpi=300)


output_filename = "combined_level1_network_graphs.jpg"  
output_path = os.path.join(FigureGraph_folder, output_filename)
fig.savefig(output_path, bbox_inches="tight", dpi=300)
fig.show()
